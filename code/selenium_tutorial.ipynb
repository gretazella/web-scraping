# %% [markdown]
# # Web Scraping with Selenium

# %% [markdown]
# Traditional scraping libraries like BeautifulSoup work well for static HTML, but they fall short on dynamic sites where content loads via user interactions (e.g., scrolling, clicking filters). Selenium bridges this gap by automating a real web browser, simulating human actions like navigating pages, clicking buttons, and waiting for elements to load. In this tutorial we are going to scrape the website "Ground News" using Selenium and JavaScript.
#
# Ground News is a unique platform that aggregates news articles from thousands of sources, rating them for bias (left, center, right) and factuality. This makes it an ideal case study for examining media polarization, sentiment analysis, visualizing bias distribution and more.
#
# We aim to collect comprehensive information on news articles related to Artificial Intelligence, including the article titles, their summaries, and the media bias ratings associated with each source. This data will be organized and saved into a CSV file for easy analysis and future reference.

# %% [markdown]
# # What You'll Learn in This Notebook

# %% [markdown]
# This notebook will walk you through:
#
# - Setting up Selenium with a web driver (e.g., ChromeDriver).
# - Navigating to Ground News and interacting with its dynamic elements (e.g., searching for topics, expanding articles)
# - Extracting data such as article titles, sources, bias ratings
# - Handling common challenges like waiting for page loads, dealing with pop-ups
#
# By the end, you'll have a foundational script that you can adapt for your own DH projects, whether analyzing news trends, social media, or archival sites.

# %%
# Import webdriver for controlling webpages
from selenium import webdriver

# Import By class to identify and select elements on the webpage
from selenium.webdriver.common.by import By

# Options are the settings you can give to the browser
from selenium.webdriver.chrome.options import Options

# # Tools for waiting until certain conditions are met on the page (e.g., element becomes clickable)
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# Import time to manually pause execution when needed (not ideal, but sometimes useful)
import time

# Import pandas to structure and store data
import pandas as pd

# %%
# Initialize Settings
opts = Options()

# Optional: open the browers without showing it on your screen
#opts.add_argument("--headless")

# Open the browser
driver = webdriver.Chrome(options=opts)

# Open the website
driver.get("https://ground.news/")

# Print the webpage's current title
driver.title
# Out:
# 'Ground News'

# %%
# Import common errors raised when the element you are searching for is not found or something blocks it
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import ElementNotInteractableException

# Set default waiting time useful when calling element-searching methods (e.g., driver.find_elements)
driver.implicitly_wait(0.5)

# Identify the onboarding button and click on it, if present, to proceed to the home page
try:
    proceed_to_webpage_button = driver.find_element(By.CSS_SELECTOR, "[data-testid='onboarding-close-button']")
    proceed_to_webpage_button.click()

# Proceed if you are already on the home page
except:
    pass
    
# List all the links in the navigation bar using CSS_SELECTOR
# This line combines CSS Selectors, it means: find any element with class "embla__slide" and then find all <a> elements inside it
links = driver.find_elements(By.CSS_SELECTOR, ".embla__slide a")

# If any link was detected using the above selectors:
if links:

    # Print the number of links found
    print(f"Found {len(links)} nav links:")

    # For each collected link:
    for link in links:

        # Print the link's text and the url
        print(link.text, link.get_attribute("href"))
# Out:
# Found 13 nav links:
# Israel-Gaza https://ground.news/interest/israeli-palestinian-conflict
# Business & Markets https://ground.news/interest/business-and-markets
# Health & Medicine https://ground.news/interest/health-and-medicine
# Trump Administration https://ground.news/interest/trump-administration_63c55b
# Environment & Climate https://ground.news/interest/environment-and-climate
# Nationalist & Illiberal Politics https://ground.news/interest/nationalist-and-illiberal-politics
#  https://ground.news/interest/migration-and-border-policy
#  https://ground.news/interest/nature-and-animals
#  https://ground.news/interest/thanksgiving
#  https://ground.news/interest/ai
#  https://ground.news/interest/extreme-weather-and-disasters
#  https://ground.news/interest/g20-summit
#  https://ground.news/interest/santa-claus

# %% [markdown]
# We successfully collected all the links in the website’s navigation bar using Selenium, though this was purely HTML extraction, which we could have also accomplished with BeautifulSoup. However, our next goal is to gather all articles related to Artificial Intelligence, which requires interacting with the page—specifically, clicking on the relevant link. Selenium is particularly useful here because it allows us to simulate user actions, such as clicking buttons or links, which is not possible with BeautifulSoup alone.
#
# Heads-up: In web automation with Selenium, you sometimes need JavaScript (JS) to click on buttons because not all elements are straightforward HTML elements that Selenium can interact with directly. Selenium can only click elements that are visible on the screen. If the element is off-screen, hidden inside a scrollable area, or if it is hidden by pop-ups, banners, or sticky headers, element.click() may fail. JS can scroll the element into view.

# %%
# Try to locate and click on the "Artificial Intelligence" topic link and click on it using the click() method 
try: 

    # Identify the topic to click on using ID, or alternatively CSS SELECTOR
    topic = driver.find_element(By.ID, "header-trending-Artificial Intelligence")
    #topic = driver.find_element(By.CSS_SELECTOR, 'a[href="/interest/ai"]')
    
    # Click on the button
    topic.click()

# Use JavaScript to scroll the topic into view and click on it if hidden
except:

    # Re-select element as the previous reference may no longer be valid.
    topic = driver.find_element(By.ID, "header-trending-Artificial Intelligence")
    
    # Scroll the element into view
    driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", topic)

    # CLick on the element
    driver.execute_script("arguments[0].click();", topic)

# Wait up to 10 seconds until the URL contains "/interest/ai"
wait = WebDriverWait(driver, 10)
wait.until(EC.url_contains("/interest/ai"))

#time.sleep(5)

# Check that you are on the correct url
print(driver.current_url)
# Out:
# https://ground.news/interest/ai

# %% [markdown]
# ## It worked! You are on the correct webpage.
#
# We can now examine the current webpage to identify and collect the articles displayed, either in full or partially, so that we can save them for further analysis.
#
# The page includes a “More Stories” button that loads additional articles. To capture all available stories, this button may need to be clicked (sometimes multiple times) until no new articles are loaded.

# %%
# While the button "more stories" is available, click on it to load all articles
while True:
    
    try:
        # Relocate the element after each iteration as the references become invalid once the page changes
        more_button = driver.find_element(By.CSS_SELECTOR, "[data-testid='load-more-stories-button']")

        # Click on the button
        more_button.click()

    # Force clicking with JavaScript if the button is hidden
    except (ElementClickInterceptedException, ElementNotInteractableException): #, ElementNotInteractableException, StaleElementReferenceException

        # Relocate the element
        more_button = driver.find_element(By.CSS_SELECTOR, "[data-testid='load-more-stories-button']")

        # Scroll into view
        driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", more_button)

        # Click on it
        driver.execute_script("arguments[0].click();", more_button)

    # Stop only when there is no "more stories" button to click on
    except NoSuchElementException:
        break    

    # Manually wait a few seconds for all articles to load
    time.sleep(2)

# %%
# Count how many articles are on the webpage
#article_count = len(driver.find_elements(By.CLASS_NAME, "group"))
article_count = len(driver.find_elements(By.CSS_SELECTOR, "div .group"))

# Initialize a list to store articles' titles and links as dictionaries
data = []

# Loop through each article on the page by index
for i in range(article_count):

    # Locate article with class name
    article = driver.find_elements(By.CSS_SELECTOR, "div .group")[i]

    # Locate url with a tag
    link = article.find_element(By.TAG_NAME, "a")

    # Extract the url address from the element
    href = link.get_attribute("href")

    # In this webpage, the title is usually stored in element h3
    try:
        title = article.find_element(By.TAG_NAME, "h3")

    # However, sometimes it is stored in element h4 instead --> you can only know this by inspecting the webpage's html
    except:
        title = article.find_element(By.TAG_NAME, "h4")

    # Print the title
    title_text = title.text

    data.append({
        "title": title_text,
        "link": href
    })

# Convert your data to a pandas dataframe
df = pd.DataFrame(data)

# Save your output to csv
df.to_csv('../data/ground_news_articles.csv', index=False, encoding='utf-8')

#driver.quit()

# %%
for index, row in df.iterrows():
    link = row['link']
    
    driver.get(link)

    try:

        bias_elements = driver.find_elements(By.CSS_SELECTOR, "ul li span")
    
        #bias = " ".join([s.text.strip() for s in spans if s.text.strip() != ""])
    
        bias_text = "".join([element.text for element in bias_elements])
        
        df.loc[index, 'bias'] = bias_text

    except:

        bias_elements = driver.find_elements(By.CSS_SELECTOR, "ul li")

        bias_text = "".join([element.text for element in bias_elements])
        
        df.loc[index, 'bias'] = bias_text
        

# Save your output to csv
df.to_csv('../data/ground_news_articles.csv', index=False, encoding='utf-8')

#driver.quit()
# Out:
# https://ground.news/article/tourists-tricked-by-fake-royal-christmas-market
# https://ground.news/article/s-and-p-500-futures-jump-as-ai-trade-attempts-comeback-led-by-alphabet-live-updates
# https://ground.news/article/apple-to-focus-on-quality-and-underlying-performance-with-ios-27-next-year-report
# https://ground.news/article/howard-lutnicks-family-business-is-cashing-in-on-data-center-deals
# https://ground.news/article/bb04df7e-9aac-4b46-b5ae-5dde5882695a
# https://ground.news/article/hydro-one-partners-with-first-nations-to-build-new-priority-transmission-line-in-ontario
# https://ground.news/article/deutsche-bank-sees-s-and-p-500-rising-to-8-000-by-end-of-2026
# https://ground.news/article/for-robert-redfords-daughter-ia-tributes-make-her-mourning-even-more-difficult
# https://ground.news/article/pennsylvania-utility-regulators-propose-special-treatment-for-data-centers_f4a5cd
# https://ground.news/article/iberdrola-strengthens-commitment-to-brazil-as-it-seeks-100-control-of-neoenergia-in-1-billion-offer_c9bb72
# https://ground.news/article/samsung-galaxy-s26-series-could-feature-perplexity-ai-alongside-bixby-for-more-complex-tasks-tipster-claims_9a8964
# https://ground.news/article/un-rights-chief-warns-over-generative-ai
# https://ground.news/article/slop-of-the-pops-macquarie-dictionary-names-its-word-of-the-year_1df6fc
# https://ground.news/article/intersec-2026-to-focus-on-ai-risk-governance-and-cybersecurity-strategy
# https://ground.news/article/stock-market-today-dow-jones-s-and-p-500-futures-rise-as-fed-hints-at-possibility-of-december-cut-pony-ai-alphabet-zoom-in-focus-spdr-s-and-p-5
# https://ground.news/article/nato-and-google-cloud-sign-multi-million-dollar-deal-for-ai-enabled-sovereign-cloud_aa592f
# https://ground.news/article/rakovina-therapeutics-inc-announces-presentation-of-second-abstract-at-the-2025-society-for-neuro-oncology-annual-meeting_0e5000
# https://ground.news/article/ai-redefines-capital-the-rise-of-agentic-economic-actors
# https://ground.news/article/s-and-p-500-futures-jump-as-ai-trade-attempts-comeback-led-by-alphabet-live-updates
# https://ground.news/article/new-offshore-drilling-plan-gets-bipartisan-pushback
# https://ground.news/article/claim-against-figure-ai-ex-security-chief-warns-that-humanoid-robots-could-kill-us
# https://ground.news/article/money-talks-with-simon-angelo-the-ai-job-squeeze
# https://ground.news/article/ram-memory-is-300-more-face-and-the-guilt-is-artificial-intelligence
# https://ground.news/article/chatgpt-told-them-they-were-special-their-families-say-it-led-to-tragedy
# https://ground.news/article/why-some-people-are-treating-chatgpt-like-a-god-and-what-that-means-for-the-future-of-faith
# https://ground.news/article/a-chilling-proportion-of-teens-now-prefer-talking-to-ai-over-a-real-person
# https://ground.news/article/did-an-ai-war-just-get-one-step-closer-putin-confirms-russia-is-planning-its-own-national-ai-taskforce
# https://ground.news/article/want-to-get-more-money-from-data-centers
# https://ground.news/article/think-before-you-click-safety-advice-from-humberside-police-ahead-of-black-friday-and-cyber-monday-sales-grimsby-live
# https://ground.news/article/more-people-are-skipping-thanksgiving-dinner-at-home-restaurant-managers-say
# https://ground.news/article/college-students-furious-when-their-course-is-taught-by-ai-instead-of-a-professor
# https://ground.news/article/apple-to-focus-on-quality-and-underlying-performance-with-ios-27-next-year-report
# https://ground.news/article/nothing-os-40-has-arrived-what-brings-you-back
# https://ground.news/article/harmonizing-ai-innovation-with-cost-risk-and-roi
# https://ground.news/article/grok-the-ai-of-elon-musk-in-torment-after-anti-semitic-remarks
# https://ground.news/article/new-partnership-aims-to-unlock-potential-of-ai-to-help-charities
# https://ground.news/article/majorie-taylor-greens-approach-is-the-first-challenge-with-someone-who-grew-up-in-the-maga-movement
# https://ground.news/article/governments-must-tackle-job-concerns-amid-global-ai-excitement-investments-pm-wong
# https://ground.news/article/you-can-buy-votes-for-20-000-in-the-morning-and-70-000-in-the-evening-election-fraud-for-the-sake-of-democracy
# https://ground.news/article/week-ahead-will-renewed-speculation-of-fed-cut-next-month-cap-the-greenback
# https://ground.news/article/napster-said-it-raised-3-billion-from-a-mystery-investor-now-the-investor-and-money-is-gone
# https://ground.news/article/g20-lula-defends-sovereign-government-in-critical-minerals-and-ia-young-pan
# https://ground.news/article/ai-must-translate-into-global-good-pm-modi
# https://ground.news/article/7-key-cross-asset-calls-for-2026-ai-em-bonds-and-more
# https://ground.news/article/thessaloniki-handcuffs-on-fugitive-for-prominent-drug-trafficking
# https://ground.news/article/first-look-at-2026-27-budget-schools-community-colleges-are-fine
# https://ground.news/article/analysis-investors-eye-holiday-season-turbulence-amid-ai-and-rate-cut-doubts
# https://ground.news/article/artificial-intelligence-is-a-motor-for-collective-well-being
# https://ground.news/article/after-a-breakup-a-japanese-woman-marries-an-avatar-she-created-on-chatgpt
# https://ground.news/article/elon-musk-shows-his-sympathy-for-ai-and-affirms-that-the-work-will-be-optional-in-the-future
# https://ground.news/article/florentino-attacks-barca-they-paid-more-than-eight-million-to-negreira
# https://ground.news/article/turkish-president-attends-g20-session-on-critical-minerals-ai
# https://ground.news/article/kingdee-is-ranked-in-idcs-asia-pacific-ai-erp-marketscape
# https://ground.news/article/as-google-eyes-exponential-surge-in-serving-capacity-analyst-says-were-entering-stage-two-of-ai-where-bottlenecks-are-physical-constraints
# https://ground.news/article/how-openais-changes-sent-some-users-spiraling-software-unplugged
# https://ground.news/article/what-happened-after-cardano-was-taken-down-by-a-kid-mapping-investor-confidence
# https://ground.news/article/how-ai-is-turning-travel-and-expense-into-a-strategic-advantage
# https://ground.news/article/miss-universe-fatima-bosch-commented-on-her-controversial-victory-for-the-first-time
# https://ground.news/article/white-house-seems-to-stop-pushing-for-the-elimination-of-federal-ai-laws
# https://ground.news/article/humanoid-robot-a2-achieves-record-breaking-106-kilometer-walk
# https://ground.news/article/cxmt-debuts-its-domestically-produced-ddr5-memory-8000-mt-s-ddr5-and-10667-mt-s-lp5x-for-servers-desktops-and-laptops
# https://ground.news/article/gen-z-loves-ai-slop-according-to-former-square-enix-executive
# https://ground.news/article/tykhe-capital-and-skyvast-are-launching-the-worlds-first-and-largest-global-grade-ai-infrastructure-tokenized-fund-at-us150m
# https://ground.news/article/ai-rivals-like-openai-nvidia-and-oracle-are-collaborating-to-build-stargatebut-a-yale-expert-says-it-violates-135-years-of-antitrust-law
# https://ground.news/article/serious-internet-disruptions-continue-and-could-worsen
# https://ground.news/article/g20-summit-several-countries-interested-in-cooperating-with-indonesia-finland-interested-in-data-center-investment
# https://ground.news/article/ai-is-helping-us-reimagine-black-friday
# https://ground.news/article/artificial-intelligence-if-the-bubble-bursts-it-could-lead-to-a-global-recession
# https://ground.news/article/signals-in-the-brain-provide-information-on-the-severity-of-parkinsons-disease
# https://ground.news/article/googles-nano-banana-pro-solves-math-problem-in-students-handwriting-major-challenge-for-schools-say-netizens
# https://ground.news/article/google-argues-doj-ad-tech-breakup-risks-business-disruption
# https://ground.news/article/showing-ai-models-how-to-cheat-in-one-task-causes-them-to-cheat-in-others-shows-anthropic-study
# https://ground.news/article/ssea-ai-reshapes-digital-asset-returns-integrating-artificial-intelligence-to-help-global
# https://ground.news/article/tourists-tricked-by-fake-royal-christmas-market
# https://ground.news/article/i-just-tested-chatgpt-51-vs-grok-41-with-9-prompts-and-theres-a-clear-winner
# https://ground.news/article/explainer-china-moves-forward-with-its-ai-plus-initiative
# https://ground.news/article/nolan-x-904-uc-intelligent-helmet-with-quin-technology-presented
# https://ground.news/article/over-1-800-engineers-hit-by-amazons-record-layoffs-that-were-not-driven-by-ai
# https://ground.news/article/this-will-make-you-richer-rich-dad-poor-dad-author-bets-on-silver-amid-2025-market-crashheres-why
# https://ground.news/article/nvidias-earnings-sparks-market-rally-bitcoins-plunge-raises-concerns
# https://ground.news/article/taiwans-foxconn-expands-ai-push-with-openai-deal
# https://ground.news/article/the-ai-bubble-waiting-for-the-bang-that-may-not-be-coming-by-a-long-way
# https://ground.news/article/google-executive-issues-dire-warning-about-future-of-ai-no-company-is-going-to-be-immune
# https://ground.news/article/polls-were-rigged-but-have-no-proof-prashant-kishor-opens-up-on-bihar-rout
# https://ground.news/article/fans-protest-politics-wrestles-around-tougher-stadium-rules
# https://ground.news/article/tax-fraud-goes-from-2026-to-the-collar
# https://ground.news/article/controversy-erupts-over-trinamool-mla-humayun-kabirs-babri-masjid-remark
# https://ground.news/article/ai-isnt-an-upgrade-its-the-new-payments-playbook
# https://ground.news/article/nvidia-pushes-quantum-computing-toward-2027-breakthrough
# https://ground.news/article/breaking-news-live-updates-need-global-compact-on-ai-to-prevent-misuse-says-pm-modi-at-g20-session-3
# https://ground.news/article/amid-the-political-turmoil-in-karnataka-cm-siddaramaiah-met-kharge-and-said-everyone-will-have-to-accept-the-decision
# https://ground.news/article/noosa-radiology-welcomes-prostate-cancer-imaging-expert
# https://ground.news/article/canada-pm-and-german-chancellor-merz-discuss-ukraine-gaza-on-g20-sidelines
# https://ground.news/article/removed-from-the-market-teddy-bear-with-ai-who-talked-about-sexuality-to-children
# https://ground.news/article/should-you-buy-nvidia-stock-after-the-companys-blowout-earnings-report-heres-what-history-says
# https://ground.news/article/for-all-the-hype-ai-isnt-transforming-our-economy-in-a-hurry
# https://ground.news/article/ron-paul-warns-the-feds-fantasy-money-is-fueling-the-ai-bubble
# https://ground.news/article/trump-administration-might-not-fight-state-ai-regulations-after-all
# https://ground.news/article/washingtons-aesthetic-surgeons-are-injured-by-customers-who-ask-them-to-make-the-mar-a-lago-face-youll-look-like-maleficent
# https://ground.news/article/cji-designate-justice-surya-kant-vows-to-tackle-backlog-of-5-crore-cases
# https://ground.news/article/nigeria-failing-children-amnesty-international-condemns-government-over-rising-school-abductions
# https://ground.news/article/cardano-fbi-after-the-network-attack-charles-hoskinson-furious-cryptocurrency-cardano-feed
# https://ground.news/article/microsoft-makes-the-community-angry-by-branding-cynics-to-those-who-dont-want-ai-on-windows-11
# https://ground.news/article/web3-instead-of-black-box-how-blockchain-should-secure-trust-in-ai
# https://ground.news/article/ai-bubble-nvidia-ceo-says-3-things-are-happening
# https://ground.news/article/xinhua-headlines-g20-makes-historic-africa-debut-as-global-south-urges-fairer-global-governance
# https://ground.news/article/joburg-commuters-grapple-with-travel-chaos-amid-g20-summit-sabc-news-breaking-news-special-reports-world-business-sport-coverage-of-all_c6c87b
# https://ground.news/article/modulemd-showcases-advanced-ai-driven-allergy-solutions-at-acaai-2025
# https://ground.news/article/cracked-ai-hacking-tools-expected-to-fuel-cyberattacks-in-2026_9516a2
# https://ground.news/article/up-police-ats-probe-two-missing-kashmiri-iit-kanpur-phd-students-amid-red-fort-blast-investigation
# https://ground.news/article/indias-g20-push-pm-modi-proposes-africa-skills-plan-and-global-drug-terror-nexus-fight
# https://ground.news/article/pakistan-activates-new-sea-me-we-6-submarine-cable-to-supercharge-global-internet-connectivity
# https://ground.news/article/malaysia-turns-palm-oil-plantations-into-ai-data-centers-and-solar-farms
# https://ground.news/article/80-to-100-hours-of-work-per-week-a-swiss-company-creates-controversy-with-its-job-offer
# https://ground.news/article/australia-canada-india-technology-and-innovation-partnership-to-deepen-collaboration-pm-modi
# https://ground.news/article/ai-cracks-galaxy-simulation_5fa77d
# https://ground.news/article/india-will-become-worlds-no-1-economy-by-2047-says-cm-naidu
# https://ground.news/article/the-cracks-emerging-in-a-3-trillion-market-and-what-we-can-learn-from-it
# https://ground.news/article/indias-priorities-shine-through-in-g20-south-africa-leaders-declaration
# https://ground.news/article/gemini-3-and-the-great-2025-denial-lessons-from-ai-misfires
# https://ground.news/article/pm-modi-calls-for-rethinking-parameters-for-global-development-outlines-three-new-initiatives-at-g20-summit
# https://ground.news/article/pm-modi-meets-italian-counterpart-giorgia-meloni-on-g20-sidelines-in-johannesburg
# https://ground.news/article/gemini-3-googles-artificial-intelligence-model-that-understands-reasons-and-creates-like-never-before_a64032
# https://ground.news/article/modi-pitches-4-major-global-initiatives-at-g20
